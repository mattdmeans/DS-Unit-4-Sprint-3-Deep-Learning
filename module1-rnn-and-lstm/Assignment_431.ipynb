# %%
from __future__ import print_function
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding
from tensorflow.keras.layers import LSTM
from tensorflow.keras.callbacks import LambdaCallback, EarlyStopping, TensorBoard
import datetime
import random
import requests
import pandas as pd
import numpy as np
import sys
import os

# %%
url = "https://www.gutenberg.org/files/100/100-0.txt"

r = requests.get(url)
r.encoding = r.apparent_encoding
data = r.text
data = data.split('\r\n')
toc = [l.strip() for l in data[44:130:2]]
# Skip the Table of Contents
data = data[135:]

# Fixing Titles
toc[9] = 'THE LIFE OF KING HENRY V'
toc[18] = 'MACBETH'
toc[24] = 'OTHELLO, THE MOOR OF VENICE'
toc[34] = 'TWELFTH NIGHT: OR, WHAT YOU WILL'

locations = {id_:{'title':title, 'start':-99} for id_,title in enumerate(toc)}

# Start 
for e,i in enumerate(data):
    for t,title in enumerate(toc):
        if title in i:
            locations[t].update({'start':e})
            

df_toc = pd.DataFrame.from_dict(locations, orient='index')
# Convert to Dataframe
df_toc['end'] = df_toc['start'].shift(-1).apply(lambda x: x-1)
df_toc.loc[42, 'end'] = len(data)
df_toc['end'] = df_toc['end'].astype('int')

df_toc['text'] = df_toc.apply(lambda x: '\r\n'.join(data[ x['start'] : int(x['end']) ]), axis=1)

# %%
df_toc
# Out:
#                                        title  ...                                               text
# 0        THE TRAGEDY OF ANTONY AND CLEOPATRA  ...
# 1                             AS YOU LIKE IT  ...  AS YOU LIKE IT\r\n\r\n\r\nDRAMATIS PERSONAE.\r...
# 2                       THE COMEDY OF ERRORS  ...  THE COMEDY OF ERRORS\r\n\r\n\r\n\r\nContents\r...
# 3                  THE TRAGEDY OF CORIOLANUS  ...  THE TRAGEDY OF CORIOLANUS\r\n\r\nDramatis Pers...
# 4                                  CYMBELINE  ...  CYMBELINE.\r\nLaud we the gods;\r\nAnd let our...
# 5   THE TRAGEDY OF HAMLET, PRINCE OF DENMARK  ...  THE TRAGEDY OF HAMLET, PRINCE OF DENMARK\r\n\r...
# 6    THE FIRST PART OF KING HENRY THE FOURTH  ...  THE FIRST PART OF KING HENRY THE FOURTH\r\n\r\...
# 7   THE SECOND PART OF KING HENRY THE FOURTH  ...  THE SECOND PART OF KING HENRY THE FOURTH\r\n\r...
# 8           THE LIFE OF KING HENRY THE FIFTH  ...
# 9                   THE LIFE OF KING HENRY V  ...  THE LIFE OF KING HENRY V\r\n\r\n\r\n\r\nConten...
# 10   THE SECOND PART OF KING HENRY THE SIXTH  ...  THE SECOND PART OF KING HENRY THE SIXTH\r\n\r\...
# 11    THE THIRD PART OF KING HENRY THE SIXTH  ...  THE THIRD PART OF KING HENRY THE SIXTH\r\n\r\n...
# 12                     KING HENRY THE EIGHTH  ...                   KING HENRY THE EIGHTH\r\n\r\n...
# 13                                 KING JOHN  ...    KING JOHN. O cousin, thou art come to set mi...
# 14              THE TRAGEDY OF JULIUS CAESAR  ...  THE TRAGEDY OF JULIUS CAESAR\r\n\r\n\r\n\r\nCo...
# 15                  THE TRAGEDY OF KING LEAR  ...  THE TRAGEDY OF KING LEAR\r\n\r\n\r\n\r\nConten...
# 16                      LOVE’S LABOUR’S LOST  ...  LOVE’S LABOUR’S LOST\r\n\r\nDramatis Personae....
# 17                    THE TRAGEDY OF MACBETH  ...
# 18                                   MACBETH  ...  MACBETH.\r\nI will not yield,\r\nTo kiss the g...
# 19                    THE MERCHANT OF VENICE  ...  THE MERCHANT OF VENICE\r\n\r\n\r\n\r\nContents...
# 20                THE MERRY WIVES OF WINDSOR  ...  THE MERRY WIVES OF WINDSOR\r\n\r\nDramatis Per...
# 21                 A MIDSUMMER NIGHT’S DREAM  ...  A MIDSUMMER NIGHT’S DREAM\r\n\r\n\r\n\r\nConte...
# 22                    MUCH ADO ABOUT NOTHING  ...   MUCH ADO ABOUT NOTHING\r\n\r\n\r\n\r\nContent...
# 23    THE TRAGEDY OF OTHELLO, MOOR OF VENICE  ...
# 24               OTHELLO, THE MOOR OF VENICE  ...  OTHELLO, THE MOOR OF VENICE\r\n\r\n\r\n\r\nCon...
# 25                   KING RICHARD THE SECOND  ...    KING RICHARD THE SECOND\r\n  JOHN OF GAUNT, ...
# 26                    KING RICHARD THE THIRD  ...  KING RICHARD THE THIRD\r\n\r\nDramatis Persona...
# 27           THE TRAGEDY OF ROMEO AND JULIET  ...  THE TRAGEDY OF ROMEO AND JULIET\r\n\r\n\r\n\r\...
# 28                   THE TAMING OF THE SHREW  ...  THE TAMING OF THE SHREW\r\n\r\n\r\n\r\nContent...
# 29                               THE TEMPEST  ...  THE TEMPEST\r\n\r\n\r\n\r\nContents\r\n\r\nACT...
# 30               THE LIFE OF TIMON OF ATHENS  ...  THE LIFE OF TIMON OF ATHENS\r\n\r\nDRAMATIS PE...
# 31           THE TRAGEDY OF TITUS ANDRONICUS  ...  THE TRAGEDY OF TITUS ANDRONICUS\r\n\r\nDramati...
# 32       THE HISTORY OF TROILUS AND CRESSIDA  ...  THE HISTORY OF TROILUS AND CRESSIDA\r\n\r\n\r\...
# 33          TWELFTH NIGHT; OR, WHAT YOU WILL  ...
# 34          TWELFTH NIGHT: OR, WHAT YOU WILL  ...  TWELFTH NIGHT: OR, WHAT YOU WILL\r\n\r\n\r\n\r...
# 35                     THE TWO NOBLE KINSMEN  ...  THE TWO NOBLE KINSMEN:\r\n\r\nPresented at the...
# 36                         THE WINTER’S TALE  ...  THE WINTER’S TALE\r\n\r\n\r\n\r\n\r\nContents\...
# 37                       A LOVER’S COMPLAINT  ...  A LOVER’S COMPLAINT\r\n\r\n\r\n\r\nFrom off a ...
# 38                    THE PASSIONATE PILGRIM  ...  THE PASSIONATE PILGRIM\r\n\r\nI.\r\n\r\nDid no...
# 39                THE PHOENIX AND THE TURTLE  ...  THE PHOENIX AND THE TURTLE\r\n\r\n\r\n\r\nLet ...
# 40                       THE RAPE OF LUCRECE  ...  THE RAPE OF LUCRECE\r\n\r\n                   ...
# 41                          VENUS AND ADONIS  ...   VENUS AND ADONIS\r\n\r\nEven as the sun with ...
# 42                                            ...
#
# [43 rows x 4 columns]

# %%
df_toc[df_toc['title'].str.match('OTHELLO, THE MOOR OF VENICE')]
# Out:
#                           title  ...                                               text
# 24  OTHELLO, THE MOOR OF VENICE  ...  OTHELLO, THE MOOR OF VENICE\r\n\r\n\r\n\r\nCon...
#
# [1 rows x 4 columns]

# %%
locations[24]
# Out:
# {'start': 103827, 'title': 'OTHELLO, THE MOOR OF VENICE'}

# %%
othello = df_toc['text'][24]
len(othello)
# Out:
# 275333

# %%
chars = list(set(othello))

char_int = {c:i for i,c in enumerate(chars)}
int_char = {i:c for i,c in enumerate(chars)}

print(f"Othello contains {len(chars)} unique characters.")
# Out:
# Othello contains 74 unique characters.

# %%
maxlen = 150
step = 1

encoded = [char_int[c] for c in othello]

sequences = [] # Each element is 40 characters long
next_chars = [] # One element for each sequence

for i in range(0, len(encoded) - maxlen, step):
    sequences.append(encoded[i : i + maxlen])
    next_chars.append(encoded[i + maxlen])
    
print('sequences:', len(sequences))
# Out:
# sequences: 275183

# %%
x = np.zeros((len(sequences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sequences), len(chars)), dtype=np.bool)

for i, sequence in enumerate(sequences):
    for t, char in enumerate(sequence):
        x[i,t,char] = 1
        
    y[i, next_chars[i]] = 1

# %%
print(x.shape, y.shape)
# Out:
# (275183, 150, 74) (275183, 74)

# %%
model = Sequential()
model.add(LSTM(256, input_shape=(maxlen, len(chars)), dropout=0.2))
model.add(Dense(len(chars), activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='nadam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 256)               338944
# _________________________________________________________________
# dense (Dense)                (None, 74)                19018
# =================================================================
# Total params: 357,962
# Trainable params: 357,962
# Non-trainable params: 0
# _________________________________________________________________

# %%
def sample(preds):
  
    """helper function to sample an index from a probability array"""
    
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / 1
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
def on_epoch_end(epoch, _):
    """Function invoked at end of each epoch. Prints generated text"""
    
    print()
    print('----- Generating text after Epoch: %d' % epoch)
    
    start_index = random.randint(0, len(othello) - maxlen - 1)
    
    generated = ''
    
    sentence = othello[start_index: start_index + maxlen]
    generated += sentence
    
    print('----- Generating with seed: ----- \n')
    sys.stdout.write(generated)
    
    print('\n\n\n-----New text: -----')

    for i in range(400):
        x_pred = np.zeros((1, maxlen, len(chars)))
        for t, char in enumerate(sentence):
            x_pred[0, t, char_int[char]] = 1
            
        preds = model.predict(x_pred, verbose=0)[0]
        next_index = sample(preds)
        next_char = int_char[next_index]
        
        sentence = sentence[1:] + next_char
        
        sys.stdout.write(next_char)
    print()
    sys.stdout.flush()
    print('\n\n')
    
    
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %%
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = TensorBoard(logdir, histogram_freq=1)

model.fit(x, y,
          batch_size=128,
          validation_split=.2,
          epochs=10,
          callbacks=[print_callback, 
                     #EarlyStopping(min_delta=.02, monitor='val_loss', patience=10),
                     tensorboard_callback])
# Out:
# Epoch 1/10
#    2/1720 [..............................] - ETA: 1:42 - loss: 2.2364WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0326s vs `on_train_batch_end` time: 0.0866s). Check your callbacks.
# 1719/1720 [============================>.] - ETA: 0s - loss: 2.0993
# ----- Generating text after Epoch: 0
# ----- Generating with seed: -----
#
# mit unto, — our sovereign.
#
# ALL.
# Live, noble Helicane!
#
# HELICANUS.
# For honour’s cause, forbear your suffrages:
# If that you love Prince Pericles
#
#
# -----New text: -----
#  om hemats eees ’th thahbrens,
# O dy for winen, mo to you by good Ware.
# Thath she hay wial iel merin thinger’d Dead;
# Ih ’tich: she lald lodent’d mpind,
#
# And a aidghei. Dimbingbow ey,
#
#
# DESDEMONA.
# O, my heavy, and with hers tho, pin to morl at of ithand
# buth mose, cather. Bie Clord,
# Thad for shame theneet’h  stild. Low bothut cour;
# We el
#
#
#
# 1720/1720 [==============================] - 56s 33ms/step - loss: 2.0994 - val_loss: 1.9668
# Epoch 2/10
# 1719/1720 [============================>.] - ETA: 0s - loss: 1.9668
# ----- Generating text after Epoch: 1
# ----- Generating with seed: -----
#
# re
# ruffians, you’ll have your daughter cover’d with a Barbary horse;
# you’ll have your nephews neigh to you; you’ll have coursers for cousins
# and ge
#
#
# -----New text: -----
#
#
#
# Thiseeg love of Eyain aloul:
# And I’st of a shals, and amod crmed,
# AFisen for goll, flr the glamat-somad ie.
# Tbal ir fexheaven teet! rhabrasteslenenne
# Dus no till-fis centandeming berke Ibvely:
# Prech entench mesteritipr. If by have; on bear,
# Let forej ut or,
# Be virenighin to euclasprmy
# Tomersed,
#
#
#
# 1720/1720 [==============================] - 57s 33ms/step - loss: 1.9669 - val_loss: 1.8690
# Epoch 3/10
# 1719/1720 [============================>.] - ETA: 0s - loss: 1.8865
# ----- Generating text after Epoch: 2
# ----- Generating with seed: -----
#
# ot assist the storm.
# Here’s all that is left living of your queen,
# A little daughter: for the sake of it,
# Be manly, and take comfort.
#
# PERICLES.
#
#
# -----New text: -----
#
# Doudd you, a ditho thurg it.
#
# PERICLES.
# Thencou’s thus, swipe apost a layy,
# Hou and be ald a du yor Beaugh,
# And not, m st. ow treele on mana rond.
# Man,
# (OF reenot gondist
# That fell himpjoteitime, wo he crurke shall
#
# Iagon it hha asppor’d, ih is himmans,
# Ir moded sanion luct will.
#
# CASSIO.
#
#
# Dongeed, Befort ay see centit, tle, mante? know inte. whos
#
#
#
# 1720/1720 [==============================] - 57s 33ms/step - loss: 1.8864 - val_loss: 1.8162
# Epoch 4/10
# 1719/1720 [============================>.] - ETA: 0s - loss: 1.8274
# ----- Generating text after Epoch: 3
# ----- Generating with seed: -----
#
# ss of your youth
# The world hath noted, and your name is great
# In mouths of wisest censure: what’s the matter,
# That you unlace your reputation thus,
#
#
# -----New text: -----
#
# And liture
#  [_Fleie._]
#
#
# Now, m’ssad wete nok af youldarde.
#
# DESDEMONA.
# Roderigo and be bet desire sou!
#
# RODERIGO.
# What, here whet soom my drachs pf shie shery,
# Do orat farthe trrt hinl’d not geiv the. I.
#
# EMILIA.
# I sirvnd hang on you the horgot.
#
# ’THELLO.
# Som, of you shabl where he or porpous he bown and tonie, my porls! Whech by [_Sing courr._]
#
# IAGO.
#
#
#
#
#
#
# 1720/1720 [==============================] - 58s 34ms/step - loss: 1.8273 - val_loss: 1.7703
# Epoch 5/10
# 1720/1720 [==============================] - ETA: 0s - loss: 1.7760
# ----- Generating text after Epoch: 4
# ----- Generating with seed: -----
#
# efore the monument of Marina at Tarsus.
#
# GOWER.
# Thus time we waste, and long leagues make short;
# Sail seas in cockles, have and wish but for’t;
# M
#
#
# -----New text: -----
# y her unjy avongcy, in a cruge you, amis—;
#
# And by fore, but I would at ho ming ne’er.
#
# THAISA.
# Retsanouvy him go fichs my love’
#
# I’ll not latale your graidy ofthim,
# For the grie us eats and him
# Whisphin lither, condes oud have nove a mours;
# If the seabornow are siffinchus bequich.
# I knod not.
#
#
#
# 1720/1720 [==============================] - 57s 33ms/step - loss: 1.7760 - val_loss: 1.7351
# Epoch 6/10
# 1720/1720 [==============================] - ETA: 0s - loss: 1.7413
# ----- Generating text after Epoch: 5
# ----- Generating with seed: -----
#
# s a-land,
#      I, King Pericles, have lost
#      This queen, worth all our mundane cost.
#      Who finds her, give her burying;
#      She was the dau
#
#
# -----New text: -----
# ghter!
#
# ToO A GERIMES.
# Who sim, in? I knyw she should came of a  reaivedy
#
# GRATIANO.
#
# Af shas af ’twan chaly that ciscet cails.
#
#  [_Exit Hellamon._]
#
#
#
# Scene I. Cyprus. Anthem intashe bentle strm’d ECisp Anterchance.
# Scene III. Cyprus.
#
#  Anter Ialovant Castio.
#
# IR. Leeedigo’s a Grinness forthing fo
#
#
#
# 1720/1720 [==============================] - 57s 33ms/step - loss: 1.7413 - val_loss: 1.7094
# Epoch 7/10
# 1719/1720 [============================>.] - ETA: 0s - loss: 1.7106
# ----- Generating text after Epoch: 6
# ----- Generating with seed: -----
#
# ling back,
# Lay not your blame on me. If you have lost him,
# Why, I have lost him too.
#
# OTHELLO.
# Had it pleas’d heaven
# To try me with affliction,
#
#
# -----New text: -----
# and He noberthosp
# This your ession woold gove thy elfio’d mark
# To hath purpoous ence counded like perd tame
# Waild not to you. Thy uss where’s bue ses, yNur tais nor
# Who de dang againttand Othelso, and twntenos.
#
# CASSIO.
# I hall eysion, ous pleame. It taly is shid a linprecs of wish
#
#
# Yeth
#
# But to suisy frem you kningt
#
# OTHELLO.
# Ay, wheme oo yo
#
#
#
# 1720/1720 [==============================] - 57s 33ms/step - loss: 1.7106 - val_loss: 1.6892
# Epoch 8/10
# 1720/1720 [==============================] - ETA: 0s - loss: 1.6816
# ----- Generating text after Epoch: 7
# ----- Generating with seed: -----
#
# et me on the rack.
# I swear ’tis better to be much abus’d
# Than but to know’t a little.
#
# IAGO.
# How now, my lord?
#
# OTHELLO.
# What sense had I of h
#
#
# -----New text: -----
# er ever Iago?
#
# MONTANO.
# Hill very see, yet Iath dangater? Faith;
# Drubletisobstom. He’s give thee, trie mentu’d.
#
#
# Ne’rt me go daughter, my hadd dear?
#
# IAGO.
#
# Why, for afteer to roctoming borrd him juars,
# Sir, gorvedand in agecion were un
# (That thou turty shall twold and jellous an akes,
# It be compartunct.
#
# DESDEMONA.
# Why, hath take dove?
# Weat s
#
#
#
# 1720/1720 [==============================] - 58s 34ms/step - loss: 1.6816 - val_loss: 1.6745
# Epoch 9/10
# 1720/1720 [==============================] - ETA: 0s - loss: 1.6536
# ----- Generating text after Epoch: 8
# ----- Generating with seed: -----
#
# h
#  Lychorida and their Attendants. Then exeunt Simonides and the rest.
#
# By many a dern and painful perch
# Of Pericles the careful search,
# By the f
#
#
# -----New text: -----
# ortute for if in sourse.
#
#
# RODERIGO.
# Dood-wet my lord, I sies.
#
# EMILIA.
# I on your hostur.
#
#  Enter Roderigo and Cenicina and Ethendan.
#
# MINTANO.
# Isepain! By. Me that, Rome.
# Fert he amili, to ravildant to speet.
#
# EMILIA.
# Come and friend, no man. As I will generat him, and I’al be gest a man
# shew, by chiegd him houth untalleavanty countiof sou
#
#
#
# 1720/1720 [==============================] - 57s 33ms/step - loss: 1.6536 - val_loss: 1.6551
# Epoch 10/10
# 1720/1720 [==============================] - ETA: 0s - loss: 1.6344
# ----- Generating text after Epoch: 9
# ----- Generating with seed: -----
#
# ch thee, grant me this,
# To leave me but a little to myself.
#
# DESDEMONA.
# Shall I deny you? No, farewell, my lord.
#
# OTHELLO.
# Farewell, my Desdemo
#
#
# -----New text: -----
# na’d soor,
# Iago, avoure I shall no them. What mightesm tow thin,
# The good lides out.
#
# DESDEMONA.
# I ’t; Iath helient, Griss-of love.
#
#  [_Exit._]
#
# EMILIA.
# That, shept a frint again.
#
#  [_Saxuns to good Roderigo._]
#
# Lonk—
#
# GRATIANO.
# Till he’e good hither’daca, At ollont hom.
#
# DESDEMONA.
# O, “y, desdemona ittlest he,
#
# Coue
#
#
#
# 1720/1720 [==============================] - 57s 33ms/step - loss: 1.6344 - val_loss: 1.6481
